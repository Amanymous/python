# %%
# 1. Write a script that take user input for a number then adds 3 to that number. Then multiplies the
# result by 2, subtract 4, then again adds 3, then print the result.

# %%
number = int(input("Input a number "))
print("Add 3:",number+3)
print("Multiply 2:",number*2)
print("Subtract 4:",number-4)
print("Again Add 3:",number+3)
# Out:
# Input a number  9
# Add 3: 12
# Multiply 2: 18
# Subtract 4: 5
# Again Add 3: 12

# %%
# 2. Write a script that takes input as Celsius and then convert Celsius to Fahrenheit. (hint:
# Fahrenheit = (Celsius * 1.8) + 32)

# %%
temp = input("Input the  temperature you like to convert? (e.g., 45F, 102C etc.) : ")
degree = int(temp[:-1])
i_convention = temp[-1]

if i_convention.upper() == "C":
  result = int(round((9 * degree) / 5 + 32))
  o_convention = "Fahrenheit"
elif i_convention.upper() == "F":
  result = int(round((degree - 32) * 5 / 9))
  o_convention = "Celsius"
else:
  print("Input proper convention.")
  quit()
print("The temperature in", o_convention, "is", result, "degrees.")
# Out:
# Input the  temperature you like to convert? (e.g., 45F, 102C etc.) :  99C
# The temperature in Fahrenheit is 210 degrees.

# %%
# 3. Write a script that takes input as radius then calculate area of circle. (hint: A = πr²)

# %%
pi=3.142
radius = float(input ("Input the radius of the circle : "))
print ("The area of the circle with radius " + str(radius) + " is: " + str(pi * radius**2))
# Out:
# Input the radius of the circle :  4
# The area of the circle with radius 4.0 is: 50.272

# %%
# 4. Write a Python script that asks users for their favourite color. Create the following output
# (assuming blue is the chosen color) (hint: use ‘+’ and ‘*’)
#  blueblueblueblueblueblueblueblueblueblue
#  blue                               blue
#  blueblueblueblueblueblueblueblueblueblue

# %%
color =input ("Enter your favorite color: ")
color1 = (color + " ") * 10
color2 = color + ("     " * 8) + " " + color
color3 = (color + " ") * 10
print(color1)
print(color2)
print(color3)
# Out:
# Enter your favorite color:  blue
# blue blue blue blue blue blue blue blue blue blue
# blue                                         blue
# blue blue blue blue blue blue blue blue blue blue

# %%
# 5. Store a person’s name, and include some whitespace characters at the beginning and end of
# the name. Make sure you use each character combination, "\t" and "\n", at least once. Print
# the name once, so the whitespace around the name is displayed. Then print the name using
# each of the three stripping functions, lstrip( ), rstrip(), and strip().

# %%
name = " Aman Mughal "
print("name:",name)
rstrip = ("\t" + name.rstrip())
print("rstrip:",rstrip)
lstrip = ("\t" + name.lstrip())
print("lstrip",lstrip)
strip = ("\t" + name.strip())
print("strip",strip)
print("Whitespace Stripping:\n\t" + rstrip + lstrip + strip)
# Out:
# name:  Aman Mughal
# rstrip: 	 Aman Mughal
# lstrip 	Aman Mughal
# strip 	Aman Mughal
# Whitespace Stripping:
# 		 Aman Mughal	Aman Mughal 	Aman Mughal
