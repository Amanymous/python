# %%
from urllib import request
from bs4 import BeautifulSoup

# %%
page="https://www.squarespace.com/"

# %%
connect=request.urlopen(page)

# %%
page_html=connect.read()

# %%
connect.close()

# %%
page_soup=BeautifulSoup(page_html,"html.parser")

# %%
page_soup.h2
# Out:
# <h2 class="home-carousel__slide__title">Make it.</h2>

# %%
page_soup.h2.text.strip()
# Out:
# 'Make it.'

# %%
heading=page_soup.h2.text.strip()
print(heading)
# Out:
# Make it.

# %%
text_div=page_soup.findAll("div",{'class':'header__sticky'})
text_div
# Out:
# [<div class="header__sticky">
#  <div class="header__container header__container--is-hidden">
#  <div class="header__logo">
#  <a class="is-borderless" href="/">
#  <svg class="squarespace-mark is-fill notranslate" height="24px" viewbox="0 0 90 72" width="30px" xmlns="http://www.w3.org/2000/svg"><title>Squarespace Logo</title><g data-name="Logo"><path d="M18.49 38.15L46.67 10A10.16 10.16 0 0 1 61 10l2.19 2.19 4.39-4.39-2.19-2.2a16.38 16.38 0 0 0-23.14 0L14.09 33.76z"></path><path d="M56.11 19.27l-4.39-4.39-28.19 28.19A10.15 10.15 0 0 1 9.18 28.71L33.5 4.39 29.11 0 4.79 24.32a16.36 16.36 0 1 0 23.13 23.14zM84.17 24.32a16.39 16.39 0 0 0-23.14 0L32.84 52.51l4.39 4.39 28.19-28.19a10.15 10.15 0 0 1 17.32 7.18 10 10 0 0 1-3 7.18L55.45 67.39l4.4 4.39 24.32-24.32a16.38 16.38 0 0 0 0-23.14z"></path><path d="M70.47 33.63L42.28 61.81a10.17 10.17 0 0 1-14.36 0l-2.19-2.2L21.34 64l2.19 2.2a16.39 16.39 0 0 0 23.14 0L74.86 38z"></path></g></svg>
# ...

# %%
text_a=text_div[0].findAll("a",{'class':'is-borderless'})
text_a
# Out:
# [<a class="is-borderless" href="/">
#  <svg class="squarespace-mark is-fill notranslate" height="24px" viewbox="0 0 90 72" width="30px" xmlns="http://www.w3.org/2000/svg"><title>Squarespace Logo</title><g data-name="Logo"><path d="M18.49 38.15L46.67 10A10.16 10.16 0 0 1 61 10l2.19 2.19 4.39-4.39-2.19-2.2a16.38 16.38 0 0 0-23.14 0L14.09 33.76z"></path><path d="M56.11 19.27l-4.39-4.39-28.19 28.19A10.15 10.15 0 0 1 9.18 28.71L33.5 4.39 29.11 0 4.79 24.32a16.36 16.36 0 1 0 23.13 23.14zM84.17 24.32a16.39 16.39 0 0 0-23.14 0L32.84 52.51l4.39 4.39 28.19-28.19a10.15 10.15 0 0 1 17.32 7.18 10 10 0 0 1-3 7.18L55.45 67.39l4.4 4.39 24.32-24.32a16.38 16.38 0 0 0 0-23.14z"></path><path d="M70.47 33.63L42.28 61.81a10.17 10.17 0 0 1-14.36 0l-2.19-2.2L21.34 64l2.19 2.2a16.39 16.39 0 0 0 23.14 0L74.86 38z"></path></g></svg>
# ...

# %%
text_svg=text_div[0].findAll("svg",{'class':'squarespace-mark is-fill notranslate'})
text_a
# Out:
# [<a class="is-borderless" href="/">
#  <svg class="squarespace-mark is-fill notranslate" height="24px" viewbox="0 0 90 72" width="30px" xmlns="http://www.w3.org/2000/svg"><title>Squarespace Logo</title><g data-name="Logo"><path d="M18.49 38.15L46.67 10A10.16 10.16 0 0 1 61 10l2.19 2.19 4.39-4.39-2.19-2.2a16.38 16.38 0 0 0-23.14 0L14.09 33.76z"></path><path d="M56.11 19.27l-4.39-4.39-28.19 28.19A10.15 10.15 0 0 1 9.18 28.71L33.5 4.39 29.11 0 4.79 24.32a16.36 16.36 0 1 0 23.13 23.14zM84.17 24.32a16.39 16.39 0 0 0-23.14 0L32.84 52.51l4.39 4.39 28.19-28.19a10.15 10.15 0 0 1 17.32 7.18 10 10 0 0 1-3 7.18L55.45 67.39l4.4 4.39 24.32-24.32a16.38 16.38 0 0 0 0-23.14z"></path><path d="M70.47 33.63L42.28 61.81a10.17 10.17 0 0 1-14.36 0l-2.19-2.2L21.34 64l2.19 2.2a16.39 16.39 0 0 0 23.14 0L74.86 38z"></path></g></svg>
# ...

# %%
text_a=text_div[0].findAll('a',{"class":"templates-link"})
text_a
# Out:
# [<a class="templates-link" data-object-identifier="templates-button" data-object-type="link" href="/templates">Templates</a>]

# %%
for text in text_div:#loop ma jo text likha ha as a variable act kar raha ha
    text_only=text.findAll("a",{'class':'is-borderless'})
    texts=text_only[0].text.strip()#or yahn isko bta rahy hain text leky ana 
    print(texts)
# Out:
# Squarespace Logo
# Squarespace Logo

# %%
for text_svg in text_div:
    svg_only=text_svg.findAll("svg",{'class':'squarespace-mark is-fill notranslate'})
    texts_svg=svg_only[0].text.strip()#yahn text is liye likha ha taky is ko bata sakain text authana ha
    print(texts_svg)
# Out:
# Squarespace Logo

# %%
#or maney uper 2 alag for loop diye lekin ma ek hi kam karsakta ha

# %%
for text in text_div:
    text_only=text.findAll("a",{'class':'is-borderless'})
    texts=text_only[0].text.strip()
    
    svg_only=text_svg.findAll("svg",{'class':'squarespace-mark is-fill notranslate'})
    texts_svg=svg_only[0].text.strip()

    print(texts_svg)
    print("=============")
    print(texts)
# Out:
# Squarespace Logo
# ...
# Squarespace Logo
# Squarespace Logo

# %%
import scrapy

# %%
class web1(scrapy.Spider):
    name='web1'
    start_url=['https://www.squarespace.com/']

# %%
def parse(self,response):#ye response request sent kar rha ha
    for web in reponse.css('div.header__sticky'):
        yield{'a_tag':web.css('a.is-borderless::text').extract(),#extract remove karaha ha sary text ko
              'svg_tag':web.css('svg.squarespace-mark is-fill notranslate::text').extract_first()#extract_first first line ko extraxct kar raha ha
             }

# %%
import requests
from scrapy.http import TextResponse

# %%
r = requests.get('https://www.squarespace.com/')
response = TextResponse(r.url, body=r.text, encoding='utf-8')

# %%
response.css('title')
# Out:
# [<Selector xpath='descendant-or-self::title' data='<title>Build a Website – Website Buil...'>,
#  <Selector xpath='descendant-or-self::title' data='<title>Squarespace Logo</title>'>,
#  <Selector xpath='descendant-or-self::title' data='<title>Squarespace Logo</title>'>,
#  <Selector xpath='descendant-or-self::title' data='<title>Squarespace Logo</title>'>,
#  <Selector xpath='descendant-or-self::title' data='<title>Squarespace Logo</title>'>,
#  <Selector xpath='descendant-or-self::title' data='<title>Squarespace Logo</title>'>,
#  <Selector xpath='descendant-or-self::title' data='<title>Squarespace Logo</title>'>]

# %%
response.css('title::text').extract()
# Out:
# ['Build a Website – Website Builder – Squarespace',
#  'Squarespace Logo',
#  'Squarespace Logo',
#  'Squarespace Logo',
#  'Squarespace Logo',
#  'Squarespace Logo',
#  'Squarespace Logo']

# %%
response.css('h1::text').extract()
# Out:
# ['\n          Squarespace is the all-in-one platform ',
#  'to build a beautiful online presence.\n        ']

# %%
header__logo=response.css("div.header__logo")

# %%
header__logo
# Out:
# [<Selector xpath="descendant-or-self::div[@class and contains(concat(' ', normalize-space(@class), ' '), ' header__logo ')]" data='<div class="header__logo">\n  <a class...'>,
#  <Selector xpath="descendant-or-self::div[@class and contains(concat(' ', normalize-space(@class), ' '), ' header__logo ')]" data='<div class="header__logo">\n  <a class...'>]

# %%
header__logo[0]
# Out:
# <Selector xpath="descendant-or-self::div[@class and contains(concat(' ', normalize-space(@class), ' '), ' header__logo ')]" data='<div class="header__logo">\n  <a class...'>

# %%
header__logo[1]
# Out:
# <Selector xpath="descendant-or-self::div[@class and contains(concat(' ', normalize-space(@class), ' '), ' header__logo ')]" data='<div class="header__logo">\n  <a class...'>

# %%
isborderless=header__logo.css("a.is-borderless::text").extract()

# %%
isborderless
# Out:
# ['\n    ',
#  '\n\n\n    \n      ',
#  '\n\n    \n  ',
#  '\n    ',
#  '\n\n\n    \n      ',
#  '\n\n    \n  ']

# %%
isborderless[0]
# Out:
# '\n    '

# %%
isborderless=header__logo.css("a.is-borderless::text").extract()

# %%
#axiom work

# %%
import requests

# %%
url="https://www.w3schools.com/"

# %%
response=requests.get(url)
response
# Out:
# <Response [200]>

# %%
from bs4 import BeautifulSoup

# %%
data=BeautifulSoup(response.text,"html.parser")
data
# Out:
# <!DOCTYPE html>
#
# <html lang="en-US">
# <head>
# <title>W3Schools Online Web Tutorials</title>
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <meta content="HTML,CSS,JavaScript,DOM,jQuery,PHP,SQL,XML,Python,Java,Bootstrap,Web,W3CSS,W3C,tutorials,programming,development,training,learning,quiz,primer,lessons,reference,examples,source code,colors,demos,tips,w3c" name="Keywords"/>
# <link href="/favicon.ico" rel="icon" type="image/x-icon"/>
# <link href="w3css/4/w3.css" rel="stylesheet"/>
# <script>
# (function() {
# var cx = '012971019331610648934:m2tou3_miwy';
# var gcse = document.createElement('script'); gcse.type = 'text/javascript'; gcse.async = true;
# gcse.src = 'https://www.google.com/cse/cse.js?cx=' + cx;
# var s = document.getElementsByTagName('script')[0]; s.parentNode.insertBefore(gcse, s);
# })();
# (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
# ...

# %%
h1=data.find_all("h1",)
h1
# Out:
# [<h1>HTML</h1>,
#  <h1>CSS</h1>,
#  <h1>CSS</h1>,
#  <h1 class="w3-jumbo">JavaScript</h1>,
#  <h1>SQL</h1>,
#  <h1>SQL</h1>]

# %%
h1=data.find_all("h1",)
h1[3]#done my me
# Out:
# <h1 class="w3-jumbo">JavaScript</h1>

# %%
w3jumbo=data.find_all("h1",class_="w3-jumbo")#find_all ki jaga find bi use karsakty hain
w3jumbo
# Out:
# [<h1 class="w3-jumbo">JavaScript</h1>]

# %%
for i in h1:
    print(i.text)
# Out:
# HTML
# CSS
# CSS
# JavaScript
# SQL
# SQL

# %%
div=data.find_all("div",class_="w3-bar-block")
len(div)
# Out:
# 5

# %%
div
# Out:
# [<div class="w3-bar-block">
#  <div class="w3-container">
#  <h4 class="w3-margin-top">HTML and CSS</h4>
#  </div>
#  <a class="w3-bar-item w3-button" href="/html/default.asp">Learn HTML</a>
#  <a class="w3-bar-item w3-button" href="/css/default.asp">Learn CSS</a>
#  <a class="w3-bar-item w3-button" href="/bootstrap/bootstrap_ver.asp">Learn Bootstrap</a>
#  <a class="w3-bar-item w3-button" href="/w3css/default.asp">Learn W3.CSS</a>
#  <a class="w3-bar-item w3-button" href="/colors/default.asp">Learn Colors</a>
#  <a class="w3-bar-item w3-button" href="/icons/default.asp">Learn Icons</a>
#  <a class="w3-bar-item w3-button" href="/graphics/default.asp">Learn Graphics</a>
#  <a class="w3-bar-item w3-button" href="/howto/default.asp">Learn How To</a>
#  <a class="w3-bar-item w3-button" href="/sass/default.asp">Learn Sass</a>
#  <div class="w3-container">
#  <h4 class="w3-margin-top">JavaScript</h4>
#  </div>
#  <a class="w3-bar-item w3-button" href="/js/default.asp">Learn JavaScript</a>
# ...

# %%
div[0]
# Out:
# <div class="w3-bar-block">
# <div class="w3-container">
# <h4 class="w3-margin-top">HTML and CSS</h4>
# </div>
# <a class="w3-bar-item w3-button" href="/html/default.asp">Learn HTML</a>
# <a class="w3-bar-item w3-button" href="/css/default.asp">Learn CSS</a>
# <a class="w3-bar-item w3-button" href="/bootstrap/bootstrap_ver.asp">Learn Bootstrap</a>
# <a class="w3-bar-item w3-button" href="/w3css/default.asp">Learn W3.CSS</a>
# <a class="w3-bar-item w3-button" href="/colors/default.asp">Learn Colors</a>
# <a class="w3-bar-item w3-button" href="/icons/default.asp">Learn Icons</a>
# <a class="w3-bar-item w3-button" href="/graphics/default.asp">Learn Graphics</a>
# <a class="w3-bar-item w3-button" href="/howto/default.asp">Learn How To</a>
# <a class="w3-bar-item w3-button" href="/sass/default.asp">Learn Sass</a>
# <div class="w3-container">
# <h4 class="w3-margin-top">JavaScript</h4>
# </div>
# <a class="w3-bar-item w3-button" href="/js/default.asp">Learn JavaScript</a>
# ...

# %%
len(div[0])
# Out:
# 141

# %%
h4=div[0].find_all("h4")
h4
# Out:
# <h4 class="w3-margin-top">HTML and CSS</h4>

# %%
a=div[0].find_all("a")
a
# Out:
# [<a class="w3-bar-item w3-button" href="/html/default.asp">Learn HTML</a>,
#  <a class="w3-bar-item w3-button" href="/css/default.asp">Learn CSS</a>,
#  <a class="w3-bar-item w3-button" href="/bootstrap/bootstrap_ver.asp">Learn Bootstrap</a>,
#  <a class="w3-bar-item w3-button" href="/w3css/default.asp">Learn W3.CSS</a>,
#  <a class="w3-bar-item w3-button" href="/colors/default.asp">Learn Colors</a>,
#  <a class="w3-bar-item w3-button" href="/icons/default.asp">Learn Icons</a>,
#  <a class="w3-bar-item w3-button" href="/graphics/default.asp">Learn Graphics</a>,
#  <a class="w3-bar-item w3-button" href="/howto/default.asp">Learn How To</a>,
#  <a class="w3-bar-item w3-button" href="/sass/default.asp">Learn Sass</a>,
#  <a class="w3-bar-item w3-button" href="/js/default.asp">Learn JavaScript</a>,
#  <a class="w3-bar-item w3-button" href="/jquery/default.asp">Learn jQuery</a>,
#  <a class="w3-bar-item w3-button" href="/react/default.asp">Learn React</a>,
# ...

# %%
for i in a:
    print(i.text)
# Out:
# Learn HTML
# Learn CSS
# Learn Bootstrap
# Learn W3.CSS
# Learn Colors
# Learn Icons
# Learn Graphics
# Learn How To
# Learn Sass
# Learn JavaScript
# Learn jQuery
# Learn React
# Learn AngularJS
# Learn JSON
# Learn AJAX
# Learn W3.JS
# Learn SQL
# Learn PHP
# Learn ASP
# Learn Node.js
# Learn Raspberry Pi
# Learn Python
# Learn Java
# Learn C++
# Learn C#
# Web Templates
# Web Statistics
# Web Certificates
# Web Editor
# Web Development
# Learn XML
# Learn XML AJAX
# Learn XML DOM
# Learn XML DTD
# Learn XML Schema
# Learn XSLT
# Learn XPath
# Learn XQuery
# HTML Reference
# CSS Reference
# JS Reference
# SQL Reference
# PHP Reference
# jQuery Reference
# Python Reference
# Bootstrap 3 Reference
# Bootstrap 4 Reference
# W3.CSS Reference
# Java Reference
# Angular Reference
# Sass Reference
# UTF-8 Reference
# HTML Exercises
# CSS Exercises
# JavaScript Exercises
# SQL Exercises
# PHP Exercises
# Python Exercises
# Java Exercises
# C++ Exercises
# C# Exercises
# ...

# %%
#new website work

# %%
url = 'https://de.kompass.com/d/westerwaldkreis/de_07_07143/'
url2 = 'https://de.kompass.com/d/westerwaldkreis/de_07_07143/page-2/'
page = 'page-'

# %%
from requests import get

# %%
response = get(url, headers={
        "accept": "text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3",
        "accept-encoding": "gzip, deflate, br",
        "accept-language": "en-US,en;q=0.9,eu;q=0.8,ur;q=0.7",
        "cache-control": "max-age=0",
        "cookie": "timezoneoffset=-300; __sc_uid_=134e0c3c08b496c4c5dddac0f597f190; _k_cty_lang=de_DE; ROUTEID=.3; cookie_kompass_allowedCookies=Wysistat%2Cws_cookie_dns%2Cwschkvisit24,c1%2Cs1%2Cns_cookietest%2Cns_session,__atuvc%2Cuid,_jsuid%2C_eventqueue,__utma%2C__utmb%2C__utmc%2C__utmz%2C__utmv,undefined; SnapABugHistory=1#; _ga=GA1.2.2015073784.1570192599; _gid=GA1.2.66095710.1570192599; JSESSIONID=126B8EE30A4605B2735D0FCEEA66019C; SnapABugRef=https%3A%2F%2Fde.kompass.com%2Fd%2Fwesterwaldkreis%2Fde_07_07143%2F%20; SnapABugUserAlias=%23; SnapABugVisit=11#1570192417; kp_uuid=62e0352f-8a5b-4e6e-92a0-f63bf723de65",
        "sec-fetch-mode": "navigate",
        "sec-fetch-site": "none",
        "sec-fetch-user": "?1",
        "upgrade-insecure-requests": "1",
        "user-agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/77.0.3865.90 Safari/537.36"
    })
response
# Out:
# <Response [200]>

# %%
type(response.text)
# Out:
# str

# %%
data=BeautifulSoup(response.text,"html.parser")
data
# Out:
# <!DOCTYPE html>
#
# <html lang="de">
# <head>
# <title>
#             Unternehmen  - Westerwaldkreis | Kompass Firmenverzeichnis </title>
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# ...

# %%
main=data.find_all("main",id="page")
main
# Out:
# [<main class="" id="page" role="main">
#  <div class="container" id="content">
#  <div id="introContentTitle">
#  <h1>
#                  Unternehmen - Westerwaldkreis</h1>
#  </div>
#  <div class="nomenclature_wrapper">
#  <div class="resultatsListe">
#  <div class="container">
#  <div class="btn-filterTitle" data-target="#resultToggle" data-toggle="collapse">
#                          Meine Suche verfeinern<span class="flaticon flaticonEbol-medical"></span>
#  </div>
#  <div class="row rowFlex">
#  <section class="col-xs-12 col-sm-3 col-md-3 resultFilter" id="resultToggle">
#  <div class="resultFilterWhite">
#  <div class="filterClose" data-target="#resultToggle" data-toggle="collapse">
#  <span class="flaticon flaticonEbol-back"></span>
#                                      Return</div>
#  <div class="filterTitle">Suchergebnisse  :
#                                      Westerwaldkreis</div>
#  <div class="classificationEasylist colClassif">
# ...

# %%
section=main.find("section",id="classifSEO")
section
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-72-6d267ddc37d1> in <module>
# ----> 1 section=main.find("section",id="classifSEO")
#       2 section
#
# ~/.local/lib/python3.7/site-packages/bs4/element.py in __getattr__(self, key)
#    1600     def __getattr__(self, key):
#    1601         raise AttributeError(
# -> 1602             "ResultSet object has no attribute '%s'. You're probably treating a list of items like a single item. Did you call find_all() when you meant to call find()?" % key
#    1603         )
#
# AttributeError: ResultSet object has no attribute 'find'. You're probably treating a list of items like a single item. Did you call find_all() when you meant to call find()?

# %%
allData=data.find("div",id="resultatDivID")
allData

# %%
listData=allData.find_all("div",class_="product-list-data")
len(listData)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-73-15efb454643e> in <module>
# ----> 1 listData=allData.find_all("div",class_="product-list-data")
#       2 len(listData)
#
# AttributeError: 'NoneType' object has no attribute 'find_all'

# %%
listData[0].children
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-76-3683dce2cc02> in <module>
# ----> 1 listData[0].children
#
# NameError: name 'listData' is not defined
